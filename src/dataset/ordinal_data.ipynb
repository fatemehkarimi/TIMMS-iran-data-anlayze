# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('valid.xlsx')

# %%
df['BSBM20F'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBM16G'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBG10'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBM19G'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBM26AA'].hist()
# Out:
# <AxesSubplot:>
