# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('valid.xlsx')

# %%
df['BSBG04'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBG12A'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BCBG14I'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BCBG16D'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BCBG17A'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BCBG19'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BTBG06D'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BTBG10'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BTBM15B'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BTBM16'].hist()
# Out:
# <AxesSubplot:>
