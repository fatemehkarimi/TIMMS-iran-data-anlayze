# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('valid.xlsx')

# %%
df['BSBGHER'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGHER'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGHER'].isna().sum()
# Out:
# 126

# %%
df['BSBGSSB'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGSSB'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGSB'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGSB'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGSLM'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGSLM'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSDGSLM'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGICM'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGICM'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGDML'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGDML'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGSCM'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGSCM'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGSVM'].hist()
# Out:
# <AxesSubplot:>

# %%
df['BSBGSVM'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['BSBGSEC'].isna().sum()
# Out:
# 5980
