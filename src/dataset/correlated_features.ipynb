# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %%
df = pd.read_excel('valid.xlsx')

# %%
plt.plot(df['BSBM42AA'], df['BSBM26AA'])

# %%
plt.plot(df['BSBM42BA'], df['BSBM26BA'])

# %%
plt.plot(df['BSBGSVM'], df['BSBGSLM'])
